# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Remove NaN Comment

# %% [markdown]
# ### Attractions

# %%
attraction_df, remove_list = pd.read_csv("attraction.csv", encoding = "utf-16"), list()

for i in range(attraction_df.shape[0]):
    if pd.isnull(attraction_df["Comments"][i]):
        remove_list.append(i)

attraction_df.drop(labels = remove_list, axis = 0, inplace = True)
attraction_df.to_csv("attraction_after.csv", encoding = "utf-16", index = False)

attraction_df
# Out:
#                                      Title    Comments  \
# 0                                     竹湖        31 則評論
# 1                                    寄梅亭        10 則評論
# 2                                清華大學成功湖       379 則評論
# 3                                    靜心湖     2,107 則評論
# 4     沃夫帕克WolfPark 親子館(新竹親子餐廳/親子景點/室內親子)       529 則評論
# ..                                     ...         ...
# 295                                 好好聚落       395 則評論
# 296                                 宮原眼科    24,400 則評論
# 297                              鳳鼻頭文化遺址       200 則評論
# 298                               高雄市忠烈祠     1,896 則評論
# 299                            德元埤旅遊服務中心        20 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E7%AB%B9%E6...
# 1    https://www.google.com/maps/place/%E5%AF%84%E6...
# 2    https://www.google.com/maps/place/%E6%B8%85%E8...
# 3    https://www.google.com/maps/place/%E9%9D%9C%E5...
# 4    https://www.google.com/maps/place/%E6%B2%83%E5...
# ..                                                 ...
# 295  https://www.google.com/maps/place/%E5%A5%BD%E5...
# 296  https://www.google.com/maps/place/%E5%AE%AE%E5...
# 297  https://www.google.com/maps/place/%E9%B3%B3%E9...
# 298  https://www.google.com/maps/place/%E9%AB%98%E9...
# 299  https://www.google.com/maps/place/%E5%BE%B7%E5...
#
# [295 rows x 3 columns]

# %% [markdown]
# ### Restaurants

# %%
restaurant_df, remove_list = pd.read_csv("restaurant.csv", encoding = "utf-16"), list()

for i in range(restaurant_df.shape[0]):
    if pd.isnull(restaurant_df["Comments"][i]):
        remove_list.append(i)

restaurant_df.drop(labels = remove_list, axis = 0, inplace = True)
restaurant_df.to_csv("restaurant_after.csv", encoding = "utf-16", index = False)

restaurant_df
# Out:
#                          Title   Comments  \
# 0     LALA Kitchen 新美式餐廳 交大店      994 則評論
# 1                    和選旅-硯宴軒      350 則評論
# 2         漢堡王Burger King 交大店      315 則評論
# 3                RINGOAL車庫餐廳      383 則評論
# 4                      橄欖樹廚房      669 則評論
# ..                         ...        ...
# 291                夠麻吉股份有限公司      409 則評論
# 292                       紓咖       20 則評論
# 293             太魯閣晶英酒店梅園中餐廳      174 則評論
# 294             CITYLINK 內湖店    1,953 則評論
# 295                     金門餐廳    1,488 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/LALA+Kitchen...
# 1    https://www.google.com/maps/place/%E5%92%8C%E9...
# 2    https://www.google.com/maps/place/%E6%BC%A2%E5...
# 3    https://www.google.com/maps/place/RINGOAL%E8%B...
# 4    https://www.google.com/maps/place/%E6%A9%84%E6...
# ..                                                 ...
# 291  https://www.google.com/maps/place/%E5%A4%A0%E9...
# 292  https://www.google.com/maps/place/%E7%B4%93%E5...
# 293  https://www.google.com/maps/place/%E5%A4%AA%E9...
# 294  https://www.google.com/maps/place/CITYLINK+%E5...
# 295  https://www.google.com/maps/place/%E9%87%91%E9...
#
# [290 rows x 3 columns]

# %% [markdown]
# ### Bookstores

# %%
bookstore_df, remove_list = pd.read_csv("bookstore.csv", encoding = "utf-16"), list()

for i in range(bookstore_df.shape[0]):
    if pd.isnull(bookstore_df["Comments"][i]):
        remove_list.append(i)

bookstore_df.drop(labels = remove_list, axis = 0, inplace = True)
bookstore_df.to_csv("bookstore_after.csv", encoding = "utf-16", index = False)

bookstore_df
# Out:
#                   Title   Comments  \
# 0       麗文校園書局(交通大學店)       68 則評論
# 1                水木書苑      763 則評論
# 2                大學書局    1,231 則評論
# 3               筆耕小書店       86 則評論
# 4         校園書房(新竹勝利店)      110 則評論
# ..                  ...        ...
# 209    書屋花甲Ｘ而立書店（台大店）       84 則評論
# 210              太平青鳥      520 則評論
# 211              書屋花甲      284 則評論
# 213             練習曲書店      342 則評論
# 214   好好生活書店｜24小時無人書店       54 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E9%BA%97%E6...
# 1    https://www.google.com/maps/place/%E6%B0%B4%E6...
# 2    https://www.google.com/maps/place/%E5%A4%A7%E5...
# 3    https://www.google.com/maps/place/%E7%AD%86%E8...
# 4    https://www.google.com/maps/place/%E6%A0%A1%E5...
# ..                                                 ...
# 209  https://www.google.com/maps/place/%E6%9B%B8%E5...
# 210  https://www.google.com/maps/place/%E5%A4%AA%E5...
# 211  https://www.google.com/maps/place/%E6%9B%B8%E5...
# 213  https://www.google.com/maps/place/%E7%B7%B4%E7...
# 214  https://www.google.com/maps/place/%E5%A5%BD%E5...
#
# [206 rows x 3 columns]

# %% [markdown]
# ### Departments

# %%
department_df, remove_list = pd.read_csv("department.csv", encoding = "utf-16"), list()

for i in range(department_df.shape[0]):
    if pd.isnull(department_df["Comments"][i]):
        remove_list.append(i)

department_df.drop(labels = remove_list, axis = 0, inplace = True)
department_df.to_csv("department_after.csv", encoding = "utf-16", index = False)

department_df
# Out:
#                   Title    Comments  \
# 0      大聯大百貨生活館(交大門市)        56 則評論
# 1             小雅10元百貨        79 則評論
# 2                水木百貨       103 則評論
# 3             小雅10元百貨        49 則評論
# 4           大信五金百貨複合館        34 則評論
# ..                  ...         ...
# 198              德安百貨     5,860 則評論
# 199   DAISO大創百貨 台南德安店       479 則評論
# 200          漢神巨蛋購物廣場    32,720 則評論
# 201              漢神百貨     8,876 則評論
# 202         太平洋百貨 屏東店     6,583 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E5%A4%A7%E8...
# 1    https://www.google.com/maps/place/%E5%B0%8F%E9...
# 2    https://www.google.com/maps/place/%E6%B0%B4%E6...
# 3    https://www.google.com/maps/place/%E5%B0%8F%E9...
# 4    https://www.google.com/maps/place/%E5%A4%A7%E4...
# ..                                                 ...
# 198  https://www.google.com/maps/place/%E5%BE%B7%E5...
# 199  https://www.google.com/maps/place/DAISO%E5%A4%...
# 200  https://www.google.com/maps/place/%E6%BC%A2%E7...
# 201  https://www.google.com/maps/place/%E6%BC%A2%E7...
# 202  https://www.google.com/maps/place/%E5%A4%AA%E5...
#
# [160 rows x 3 columns]

# %% [markdown]
# ### Nightmarkets

# %%
nightmarket_df, remove_list = pd.read_csv("nightmarket.csv", encoding = "utf-16"), list()

for i in range(nightmarket_df.shape[0]):
    if pd.isnull(nightmarket_df["Comments"][i]):
        remove_list.append(i)

nightmarket_df.drop(labels = remove_list, axis = 0, inplace = True)
nightmarket_df.to_csv("nightmarket_after.csv", encoding = "utf-16", index = False)

nightmarket_df
# Out:
#             Title    Comments  \
# 0        新竹慈雲夜市     1,346 則評論
# 1         青草湖夜市       762 則評論
# 2          竹中夜市        73 則評論
# 3     新竹市觀光夜市協會         2 則評論
# 4      新竹市城隍廟夜市     9,105 則評論
# ..            ...         ...
# 113      新夜市鴨肉麵        51 則評論
# 114     嘉義文化路夜市    22,108 則評論
# 115       士林鹽水雞        66 則評論
# 116        彌陀夜市     2,228 則評論
# 117       極品麻油雞         4 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E6%96%B0%E7...
# 1    https://www.google.com/maps/place/%E9%9D%92%E8...
# 2    https://www.google.com/maps/place/%E7%AB%B9%E4...
# 3    https://www.google.com/maps/place/%E6%96%B0%E7...
# 4    https://www.google.com/maps/place/%E6%96%B0%E7...
# ..                                                 ...
# 113  https://www.google.com/maps/place/%E6%96%B0%E5...
# 114  https://www.google.com/maps/place/%E5%98%89%E7...
# 115  https://www.google.com/maps/place/%E5%A3%AB%E6...
# 116  https://www.google.com/maps/place/%E5%BD%8C%E9...
# 117  https://www.google.com/maps/place/%E6%A5%B5%E5...
#
# [116 rows x 3 columns]

# %% [markdown]
# ### Outlets

# %%
outlet_df, remove_list = pd.read_csv("outlet.csv", encoding = "utf-16"), list()

for i in range(outlet_df.shape[0]):
    if pd.isnull(outlet_df["Comments"][i]):
        remove_list.append(i)

outlet_df.drop(labels = remove_list, axis = 0, inplace = True)
outlet_df.to_csv("outlet_after.csv", encoding = "utf-16", index = False)

outlet_df
# Out:
#                            Title    Comments  \
# 0       Timberland 新竹愛買 Outlet        22 則評論
# 2          GLORIA OUTLETS華泰名品城    36,364 則評論
# 3        MITSUI OUTLET PARK 林口    38,888 則評論
# 4                麗寶Outlet Mall    21,671 則評論
# 5     UNDER ARMOUR 林口三井OUTLET店     2,211 則評論
# ..                           ...         ...
# 193         御殿場PREMIUM OUTLETS    20,135 則評論
# 194          三井OUTLET PARK 木更津    12,904 則評論
# 195           SHIATZY CHEN 夏姿陳         4 則評論
# 196           三井OUTLET PARK 幕張     7,749 則評論
# 197           三井OUTLET PARK 入間     9,769 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/Timberland+%...
# 2    https://www.google.com/maps/place/GLORIA+OUTLE...
# 3    https://www.google.com/maps/place/MITSUI+OUTLE...
# 4    https://www.google.com/maps/place/%E9%BA%97%E5...
# 5    https://www.google.com/maps/place/UNDER+ARMOUR...
# ..                                                 ...
# 193  https://www.google.com/maps/place/%E5%BE%A1%E6...
# 194  https://www.google.com/maps/place/%E4%B8%89%E4...
# 195  https://www.google.com/maps/place/SHIATZY+CHEN...
# 196  https://www.google.com/maps/place/%E4%B8%89%E4...
# 197  https://www.google.com/maps/place/%E4%B8%89%E4...
#
# [184 rows x 3 columns]

# %% [markdown]
# ### Clinic

# %%
clinic_df, remove_list = pd.read_csv("clinic.csv", encoding = "utf-16"), list()

for i in range(clinic_df.shape[0]):
    if pd.isnull(clinic_df["Comments"][i]):
        remove_list.append(i)

clinic_df.drop(labels = remove_list, axis = 0, inplace = True)
clinic_df.to_csv("clinic_after.csv", encoding = "utf-16", index = False)

clinic_df
# Out:
#                                  Title Comments  \
# 0                               康德診所    165 則評論
# 1                               長春診所    462 則評論
# 2                             和杏中醫診所     55 則評論
# 3                              茱麗婦產科     74 則評論
# 4                            倪耳鼻喉科診所     74 則評論
# ..                                 ...      ...
# 87                              輔大診所    311 則評論
# 88                            桃園聖宜診所    842 則評論
# 89                             蕭正貴診所    104 則評論
# 90                              自立診所     41 則評論
# 91   桃園中壢長慎醫院-糖尿病/新陳代謝科/腎臟病/一般內科推薦醫院     68 則評論
#
#                                                   Url
# 0   https://www.google.com/maps/place/%E5%BA%B7%E5...
# 1   https://www.google.com/maps/place/%E9%95%B7%E6...
# 2   https://www.google.com/maps/place/%E5%92%8C%E6...
# 3   https://www.google.com/maps/place/%E8%8C%B1%E9...
# 4   https://www.google.com/maps/place/%E5%80%AA%E8...
# ..                                                ...
# 87  https://www.google.com/maps/place/%E8%BC%94%E5...
# 88  https://www.google.com/maps/place/%E6%A1%83%E5...
# 89  https://www.google.com/maps/place/%E8%95%AD%E6...
# 90  https://www.google.com/maps/place/%E8%87%AA%E7...
# 91  https://www.google.com/maps/place/%E6%A1%83%E5...
#
# [91 rows x 3 columns]

# %% [markdown]
# ### Hospital

# %%
hospital_df, remove_list = pd.read_csv("hospital.csv", encoding = "utf-16"), list()

for i in range(hospital_df.shape[0]):
    if pd.isnull(hospital_df["Comments"][i]):
        remove_list.append(i)

hospital_df.drop(labels = remove_list, axis = 0, inplace = True)
hospital_df.to_csv("hospital_after.csv", encoding = "utf-16", index = False)

hospital_df
# Out:
#                   Title Comments  \
# 0          馬偕紀念醫院新竹院區    939 則評論
# 1            新竹馬偕紀念醫院     10 則評論
# 2     新竹科學工業園區管理局員工診所     78 則評論
# 3              南門綜合醫院    211 則評論
# 4            新竹國泰綜合醫院    754 則評論
# ..                  ...      ...
# 162            台灣醫院協會      3 則評論
# 163            新竹縣衛生局     60 則評論
# 164            花蓮慈濟醫院    439 則評論
# 165     中國醫藥大學附設醫院急診部    249 則評論
# 166               卓醫院    129 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E9%A6%AC%E5...
# 1    https://www.google.com/maps/place/%E6%96%B0%E7...
# 2    https://www.google.com/maps/place/%E6%96%B0%E7...
# 3    https://www.google.com/maps/place/%E5%8D%97%E9...
# 4    https://www.google.com/maps/place/%E6%96%B0%E7...
# ..                                                 ...
# 162  https://www.google.com/maps/place/%E5%8F%B0%E7...
# 163  https://www.google.com/maps/place/%E6%96%B0%E7...
# 164  https://www.google.com/maps/place/%E8%8A%B1%E8...
# 165  https://www.google.com/maps/place/%E4%B8%AD%E5...
# 166  https://www.google.com/maps/place/%E5%8D%93%E9...
#
# [157 rows x 3 columns]

# %% [markdown]
# ## Remove Duplicate

# %% [markdown]
# ### Attractions

# %%
attraction_after_df, records, remove_list = pd.read_csv("attraction_after.csv", encoding = "utf-16"), set(), list()

for i in range(attraction_after_df.shape[0]):
    if attraction_after_df["Title"][i] in records:
        remove_list.append(i)
    else:
        records.add(attraction_after_df["Title"][i])
        
attraction_after_df.drop(labels = remove_list, axis = 0, inplace = True)
attraction_after_df.to_csv("attraction_after.csv", encoding = "utf-16", index = False)

attraction_after_df
# Out:
#                                      Title    Comments  \
# 0                                     竹湖        31 則評論
# 1                                    寄梅亭        10 則評論
# 2                                清華大學成功湖       379 則評論
# 3                                    靜心湖     2,107 則評論
# 4     沃夫帕克WolfPark 親子館(新竹親子餐廳/親子景點/室內親子)       529 則評論
# ..                                     ...         ...
# 290                                 好好聚落       395 則評論
# 291                                 宮原眼科    24,400 則評論
# 292                              鳳鼻頭文化遺址       200 則評論
# 293                               高雄市忠烈祠     1,896 則評論
# 294                            德元埤旅遊服務中心        20 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E7%AB%B9%E6...
# 1    https://www.google.com/maps/place/%E5%AF%84%E6...
# 2    https://www.google.com/maps/place/%E6%B8%85%E8...
# 3    https://www.google.com/maps/place/%E9%9D%9C%E5...
# 4    https://www.google.com/maps/place/%E6%B2%83%E5...
# ..                                                 ...
# 290  https://www.google.com/maps/place/%E5%A5%BD%E5...
# 291  https://www.google.com/maps/place/%E5%AE%AE%E5...
# 292  https://www.google.com/maps/place/%E9%B3%B3%E9...
# 293  https://www.google.com/maps/place/%E9%AB%98%E9...
# 294  https://www.google.com/maps/place/%E5%BE%B7%E5...
#
# [294 rows x 3 columns]

# %% [markdown]
# ### Restaurants

# %%
restaurant_after_df, records, remove_list = pd.read_csv("restaurant_after.csv", encoding = "utf-16"), set(), list()

for i in range(restaurant_after_df.shape[0]):
    if restaurant_after_df["Title"][i] in records:
        remove_list.append(i)
    else:
        records.add(restaurant_after_df["Title"][i])
        
restaurant_after_df.drop(labels = remove_list, axis = 0, inplace = True)
restaurant_after_df.to_csv("restaurant_after.csv", encoding = "utf-16", index = False)

restaurant_after_df
# Out:
#                          Title   Comments  \
# 0     LALA Kitchen 新美式餐廳 交大店      994 則評論
# 1                    和選旅-硯宴軒      350 則評論
# 2         漢堡王Burger King 交大店      315 則評論
# 3                RINGOAL車庫餐廳      383 則評論
# 4                      橄欖樹廚房      669 則評論
# ..                         ...        ...
# 285                夠麻吉股份有限公司      409 則評論
# 286                       紓咖       20 則評論
# 287             太魯閣晶英酒店梅園中餐廳      174 則評論
# 288             CITYLINK 內湖店    1,953 則評論
# 289                     金門餐廳    1,488 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/LALA+Kitchen...
# 1    https://www.google.com/maps/place/%E5%92%8C%E9...
# 2    https://www.google.com/maps/place/%E6%BC%A2%E5...
# 3    https://www.google.com/maps/place/RINGOAL%E8%B...
# 4    https://www.google.com/maps/place/%E6%A9%84%E6...
# ..                                                 ...
# 285  https://www.google.com/maps/place/%E5%A4%A0%E9...
# 286  https://www.google.com/maps/place/%E7%B4%93%E5...
# 287  https://www.google.com/maps/place/%E5%A4%AA%E9...
# 288  https://www.google.com/maps/place/CITYLINK+%E5...
# 289  https://www.google.com/maps/place/%E9%87%91%E9...
#
# [274 rows x 3 columns]

# %% [markdown]
# ### Bookstores

# %%
bookstore_after_df, records, remove_list = pd.read_csv("bookstore_after.csv", encoding = "utf-16"), set(), list()

for i in range(bookstore_after_df.shape[0]):
    if bookstore_after_df["Title"][i] in records:
        remove_list.append(i)
    else:
        records.add(bookstore_after_df["Title"][i])
        
bookstore_after_df.drop(labels = remove_list, axis = 0, inplace = True)
bookstore_after_df.to_csv("bookstore_after.csv", encoding = "utf-16", index = False)

bookstore_after_df
# Out:
#                   Title   Comments  \
# 0       麗文校園書局(交通大學店)       68 則評論
# 1                水木書苑      763 則評論
# 2                大學書局    1,231 則評論
# 3               筆耕小書店       86 則評論
# 4         校園書房(新竹勝利店)      110 則評論
# ..                  ...        ...
# 201    書屋花甲Ｘ而立書店（台大店）       84 則評論
# 202              太平青鳥      520 則評論
# 203              書屋花甲      284 則評論
# 204             練習曲書店      342 則評論
# 205   好好生活書店｜24小時無人書店       54 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E9%BA%97%E6...
# 1    https://www.google.com/maps/place/%E6%B0%B4%E6...
# 2    https://www.google.com/maps/place/%E5%A4%A7%E5...
# 3    https://www.google.com/maps/place/%E7%AD%86%E8...
# 4    https://www.google.com/maps/place/%E6%A0%A1%E5...
# ..                                                 ...
# 201  https://www.google.com/maps/place/%E6%9B%B8%E5...
# 202  https://www.google.com/maps/place/%E5%A4%AA%E5...
# 203  https://www.google.com/maps/place/%E6%9B%B8%E5...
# 204  https://www.google.com/maps/place/%E7%B7%B4%E7...
# 205  https://www.google.com/maps/place/%E5%A5%BD%E5...
#
# [203 rows x 3 columns]

# %% [markdown]
# ### Departments

# %%
department_after_df, records, remove_list = pd.read_csv("department_after.csv", encoding = "utf-16"), set(), list()

for i in range(department_after_df.shape[0]):
    if department_after_df["Title"][i] in records:
        remove_list.append(i)
    else:
        records.add(department_after_df["Title"][i])
        
department_after_df.drop(labels = remove_list, axis = 0, inplace = True)
department_after_df.to_csv("department_after.csv", encoding = "utf-16", index = False)

department_after_df
# Out:
#                   Title    Comments  \
# 0      大聯大百貨生活館(交大門市)        56 則評論
# 1             小雅10元百貨        79 則評論
# 2                水木百貨       103 則評論
# 4           大信五金百貨複合館        34 則評論
# 5              時代生活百貨        26 則評論
# ..                  ...         ...
# 155              德安百貨     5,860 則評論
# 156   DAISO大創百貨 台南德安店       479 則評論
# 157          漢神巨蛋購物廣場    32,720 則評論
# 158              漢神百貨     8,876 則評論
# 159         太平洋百貨 屏東店     6,583 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E5%A4%A7%E8...
# 1    https://www.google.com/maps/place/%E5%B0%8F%E9...
# 2    https://www.google.com/maps/place/%E6%B0%B4%E6...
# 4    https://www.google.com/maps/place/%E5%A4%A7%E4...
# 5    https://www.google.com/maps/place/%E6%99%82%E4...
# ..                                                 ...
# 155  https://www.google.com/maps/place/%E5%BE%B7%E5...
# 156  https://www.google.com/maps/place/DAISO%E5%A4%...
# 157  https://www.google.com/maps/place/%E6%BC%A2%E7...
# 158  https://www.google.com/maps/place/%E6%BC%A2%E7...
# 159  https://www.google.com/maps/place/%E5%A4%AA%E5...
#
# [151 rows x 3 columns]

# %% [markdown]
# ### Nightmarkets

# %%
nightmarket_after_df, records, remove_list = pd.read_csv("nightmarket_after.csv", encoding = "utf-16"), set(), list()

for i in range(nightmarket_after_df.shape[0]):
    if nightmarket_after_df["Title"][i] in records:
        remove_list.append(i)
    else:
        records.add(nightmarket_after_df["Title"][i])
        
nightmarket_after_df.drop(labels = remove_list, axis = 0, inplace = True)
nightmarket_after_df.to_csv("nightmarket_after.csv", encoding = "utf-16", index = False)

nightmarket_after_df
# Out:
#             Title    Comments  \
# 0        新竹慈雲夜市     1,346 則評論
# 1         青草湖夜市       762 則評論
# 2          竹中夜市        73 則評論
# 3     新竹市觀光夜市協會         2 則評論
# 4      新竹市城隍廟夜市     9,105 則評論
# ..            ...         ...
# 111      新夜市鴨肉麵        51 則評論
# 112     嘉義文化路夜市    22,108 則評論
# 113       士林鹽水雞        66 則評論
# 114        彌陀夜市     2,228 則評論
# 115       極品麻油雞         4 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E6%96%B0%E7...
# 1    https://www.google.com/maps/place/%E9%9D%92%E8...
# 2    https://www.google.com/maps/place/%E7%AB%B9%E4...
# 3    https://www.google.com/maps/place/%E6%96%B0%E7...
# 4    https://www.google.com/maps/place/%E6%96%B0%E7...
# ..                                                 ...
# 111  https://www.google.com/maps/place/%E6%96%B0%E5...
# 112  https://www.google.com/maps/place/%E5%98%89%E7...
# 113  https://www.google.com/maps/place/%E5%A3%AB%E6...
# 114  https://www.google.com/maps/place/%E5%BD%8C%E9...
# 115  https://www.google.com/maps/place/%E6%A5%B5%E5...
#
# [114 rows x 3 columns]

# %% [markdown]
# ### Outlets

# %%
outlet_after_df, records, remove_list = pd.read_csv("outlet_after.csv", encoding = "utf-16"), set(), list()

for i in range(outlet_after_df.shape[0]):
    if outlet_after_df["Title"][i] in records:
        remove_list.append(i)
    else:
        records.add(outlet_after_df["Title"][i])
        
outlet_after_df.drop(labels = remove_list, axis = 0, inplace = True)
outlet_after_df.to_csv("outlet_after.csv", encoding = "utf-16", index = False)

outlet_after_df
# Out:
#                            Title    Comments  \
# 0       Timberland 新竹愛買 Outlet        22 則評論
# 1          GLORIA OUTLETS華泰名品城    36,364 則評論
# 2        MITSUI OUTLET PARK 林口    38,888 則評論
# 3                麗寶Outlet Mall    21,671 則評論
# 4     UNDER ARMOUR 林口三井OUTLET店     2,211 則評論
# ..                           ...         ...
# 179         御殿場PREMIUM OUTLETS    20,135 則評論
# 180          三井OUTLET PARK 木更津    12,904 則評論
# 181           SHIATZY CHEN 夏姿陳         4 則評論
# 182           三井OUTLET PARK 幕張     7,749 則評論
# 183           三井OUTLET PARK 入間     9,769 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/Timberland+%...
# 1    https://www.google.com/maps/place/GLORIA+OUTLE...
# 2    https://www.google.com/maps/place/MITSUI+OUTLE...
# 3    https://www.google.com/maps/place/%E9%BA%97%E5...
# 4    https://www.google.com/maps/place/UNDER+ARMOUR...
# ..                                                 ...
# 179  https://www.google.com/maps/place/%E5%BE%A1%E6...
# 180  https://www.google.com/maps/place/%E4%B8%89%E4...
# 181  https://www.google.com/maps/place/SHIATZY+CHEN...
# 182  https://www.google.com/maps/place/%E4%B8%89%E4...
# 183  https://www.google.com/maps/place/%E4%B8%89%E4...
#
# [183 rows x 3 columns]

# %% [markdown]
# ### Clinic

# %%
clinic_after_df, records, remove_list = pd.read_csv("clinic_after.csv", encoding = "utf-16"), set(), list()

for i in range(clinic_after_df.shape[0]):
    if clinic_after_df["Title"][i] in records:
        remove_list.append(i)
    else:
        records.add(clinic_after_df["Title"][i])
        
clinic_after_df.drop(labels = remove_list, axis = 0, inplace = True)
clinic_after_df.to_csv("clinic_after.csv", encoding = "utf-16", index = False)

clinic_after_df
# Out:
#                                  Title Comments  \
# 0                               康德診所    165 則評論
# 1                               長春診所    462 則評論
# 2                             和杏中醫診所     55 則評論
# 3                              茱麗婦產科     74 則評論
# 4                            倪耳鼻喉科診所     74 則評論
# ..                                 ...      ...
# 86                              輔大診所    311 則評論
# 87                            桃園聖宜診所    842 則評論
# 88                             蕭正貴診所    104 則評論
# 89                              自立診所     41 則評論
# 90   桃園中壢長慎醫院-糖尿病/新陳代謝科/腎臟病/一般內科推薦醫院     68 則評論
#
#                                                   Url
# 0   https://www.google.com/maps/place/%E5%BA%B7%E5...
# 1   https://www.google.com/maps/place/%E9%95%B7%E6...
# 2   https://www.google.com/maps/place/%E5%92%8C%E6...
# 3   https://www.google.com/maps/place/%E8%8C%B1%E9...
# 4   https://www.google.com/maps/place/%E5%80%AA%E8...
# ..                                                ...
# 86  https://www.google.com/maps/place/%E8%BC%94%E5...
# 87  https://www.google.com/maps/place/%E6%A1%83%E5...
# 88  https://www.google.com/maps/place/%E8%95%AD%E6...
# 89  https://www.google.com/maps/place/%E8%87%AA%E7...
# 90  https://www.google.com/maps/place/%E6%A1%83%E5...
#
# [91 rows x 3 columns]

# %% [markdown]
# ### Hospital

# %%
hospital_after_df, records, remove_list = pd.read_csv("hospital_after.csv", encoding = "utf-16"), set(), list()

for i in range(hospital_after_df.shape[0]):
    if hospital_after_df["Title"][i] in records:
        remove_list.append(i)
    else:
        records.add(hospital_after_df["Title"][i])
        
hospital_after_df.drop(labels = remove_list, axis = 0, inplace = True)
hospital_after_df.to_csv("hospital_after.csv", encoding = "utf-16", index = False)

hospital_after_df
# Out:
#                   Title Comments  \
# 0          馬偕紀念醫院新竹院區    939 則評論
# 1            新竹馬偕紀念醫院     10 則評論
# 2     新竹科學工業園區管理局員工診所     78 則評論
# 3              南門綜合醫院    211 則評論
# 4            新竹國泰綜合醫院    754 則評論
# ..                  ...      ...
# 152            台灣醫院協會      3 則評論
# 153            新竹縣衛生局     60 則評論
# 154            花蓮慈濟醫院    439 則評論
# 155     中國醫藥大學附設醫院急診部    249 則評論
# 156               卓醫院    129 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E9%A6%AC%E5...
# 1    https://www.google.com/maps/place/%E6%96%B0%E7...
# 2    https://www.google.com/maps/place/%E6%96%B0%E7...
# 3    https://www.google.com/maps/place/%E5%8D%97%E9...
# 4    https://www.google.com/maps/place/%E6%96%B0%E7...
# ..                                                 ...
# 152  https://www.google.com/maps/place/%E5%8F%B0%E7...
# 153  https://www.google.com/maps/place/%E6%96%B0%E7...
# 154  https://www.google.com/maps/place/%E8%8A%B1%E8...
# 155  https://www.google.com/maps/place/%E4%B8%AD%E5...
# 156  https://www.google.com/maps/place/%E5%8D%93%E9...
#
# [157 rows x 3 columns]

# %% [markdown]
# ## Combination

# %% [markdown]
# ### Before

# %%
department_after_df = pd.read_csv("department_after.csv", encoding = "utf-16")
nightmarket_after_df = pd.read_csv("nightmarket_after.csv", encoding = "utf-16")
outlet_after_df = pd.read_csv("outlet_after.csv", encoding = "utf-16")

shopping_df = pd.concat([department_after_df, nightmarket_after_df, outlet_after_df])
shopping_df.to_csv("shopping.csv", encoding = "utf-16", index = False)

shopping_df
# Out:
#                      Title    Comments  \
# 0         大聯大百貨生活館(交大門市)        56 則評論
# 1                小雅10元百貨        79 則評論
# 2                   水木百貨       103 則評論
# 3              大信五金百貨複合館        34 則評論
# 4                 時代生活百貨        26 則評論
# ..                     ...         ...
# 178   御殿場PREMIUM OUTLETS    20,135 則評論
# 179    三井OUTLET PARK 木更津    12,904 則評論
# 180     SHIATZY CHEN 夏姿陳         4 則評論
# 181     三井OUTLET PARK 幕張     7,749 則評論
# 182     三井OUTLET PARK 入間     9,769 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E5%A4%A7%E8...
# 1    https://www.google.com/maps/place/%E5%B0%8F%E9...
# 2    https://www.google.com/maps/place/%E6%B0%B4%E6...
# 3    https://www.google.com/maps/place/%E5%A4%A7%E4...
# 4    https://www.google.com/maps/place/%E6%99%82%E4...
# ..                                                 ...
# 178  https://www.google.com/maps/place/%E5%BE%A1%E6...
# 179  https://www.google.com/maps/place/%E4%B8%89%E4...
# 180  https://www.google.com/maps/place/SHIATZY+CHEN...
# 181  https://www.google.com/maps/place/%E4%B8%89%E4...
# 182  https://www.google.com/maps/place/%E4%B8%89%E4...
#
# [448 rows x 3 columns]

# %%
clinic_after_df = pd.read_csv("clinic_after.csv", encoding = "utf-16")
hospital_after_df = pd.read_csv("hospital_after.csv", encoding = "utf-16")

medical_df = pd.concat([clinic_after_df, hospital_after_df])
medical_df.to_csv("medical.csv", encoding = "utf-16", index = False)

medical_df
# Out:
#                 Title Comments  \
# 0              康德診所    165 則評論
# 1              長春診所    462 則評論
# 2            和杏中醫診所     55 則評論
# 3             茱麗婦產科     74 則評論
# 4           倪耳鼻喉科診所     74 則評論
# ..                ...      ...
# 152          台灣醫院協會      3 則評論
# 153          新竹縣衛生局     60 則評論
# 154          花蓮慈濟醫院    439 則評論
# 155   中國醫藥大學附設醫院急診部    249 則評論
# 156             卓醫院    129 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E5%BA%B7%E5...
# 1    https://www.google.com/maps/place/%E9%95%B7%E6...
# 2    https://www.google.com/maps/place/%E5%92%8C%E6...
# 3    https://www.google.com/maps/place/%E8%8C%B1%E9...
# 4    https://www.google.com/maps/place/%E5%80%AA%E8...
# ..                                                 ...
# 152  https://www.google.com/maps/place/%E5%8F%B0%E7...
# 153  https://www.google.com/maps/place/%E6%96%B0%E7...
# 154  https://www.google.com/maps/place/%E8%8A%B1%E8...
# 155  https://www.google.com/maps/place/%E4%B8%AD%E5...
# 156  https://www.google.com/maps/place/%E5%8D%93%E9...
#
# [248 rows x 3 columns]

# %% [markdown]
# ### After

# %%
shopping_df, remove_list = pd.read_csv("shopping.csv", encoding = "utf-16"), list()

for i in range(shopping_df.shape[0]):
    comments = shopping_df["Comments"][i]
    comments = int(comments[0:comments.find("則評論")].replace(',', ''))
    if comments <= 25: remove_list.append(i)

shopping_df.drop(remove_list, axis = 0, inplace = True)
shopping_df.to_csv("shopping_after.csv", encoding = "utf-16", index = False)

shopping_df
# Out:
#                      Title    Comments  \
# 0         大聯大百貨生活館(交大門市)        56 則評論
# 1                小雅10元百貨        79 則評論
# 2                   水木百貨       103 則評論
# 3              大信五金百貨複合館        34 則評論
# 4                 時代生活百貨        26 則評論
# ..                     ...         ...
# 441           寶島鐘錶 林口三井店       107 則評論
# 443   御殿場PREMIUM OUTLETS    20,135 則評論
# 444    三井OUTLET PARK 木更津    12,904 則評論
# 446     三井OUTLET PARK 幕張     7,749 則評論
# 447     三井OUTLET PARK 入間     9,769 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E5%A4%A7%E8...
# 1    https://www.google.com/maps/place/%E5%B0%8F%E9...
# 2    https://www.google.com/maps/place/%E6%B0%B4%E6...
# 3    https://www.google.com/maps/place/%E5%A4%A7%E4...
# 4    https://www.google.com/maps/place/%E6%99%82%E4...
# ..                                                 ...
# 441  https://www.google.com/maps/place/%E5%AF%B6%E5...
# 443  https://www.google.com/maps/place/%E5%BE%A1%E6...
# 444  https://www.google.com/maps/place/%E4%B8%89%E4...
# 446  https://www.google.com/maps/place/%E4%B8%89%E4...
# 447  https://www.google.com/maps/place/%E4%B8%89%E4...
#
# [296 rows x 3 columns]

# %%
medical_df, remove_list = pd.read_csv("medical.csv", encoding = "utf-16"), list()

for i in range(medical_df.shape[0]):
    comments = medical_df["Comments"][i]
    comments = int(comments[0:comments.find("則評論")].replace(',', ''))
    # if comments <= 25: remove_list.append(i)

medical_df.drop(remove_list, axis = 0, inplace = True)
medical_df.to_csv("medical_after.csv", encoding = "utf-16", index = False)

medical_df
# Out:
#                 Title Comments  \
# 0              康德診所    165 則評論
# 1              長春診所    462 則評論
# 2            和杏中醫診所     55 則評論
# 3             茱麗婦產科     74 則評論
# 4           倪耳鼻喉科診所     74 則評論
# ..                ...      ...
# 243          台灣醫院協會      3 則評論
# 244          新竹縣衛生局     60 則評論
# 245          花蓮慈濟醫院    439 則評論
# 246   中國醫藥大學附設醫院急診部    249 則評論
# 247             卓醫院    129 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E5%BA%B7%E5...
# 1    https://www.google.com/maps/place/%E9%95%B7%E6...
# 2    https://www.google.com/maps/place/%E5%92%8C%E6...
# 3    https://www.google.com/maps/place/%E8%8C%B1%E9...
# 4    https://www.google.com/maps/place/%E5%80%AA%E8...
# ..                                                 ...
# 243  https://www.google.com/maps/place/%E5%8F%B0%E7...
# 244  https://www.google.com/maps/place/%E6%96%B0%E7...
# 245  https://www.google.com/maps/place/%E8%8A%B1%E8...
# 246  https://www.google.com/maps/place/%E4%B8%AD%E5...
# 247  https://www.google.com/maps/place/%E5%8D%93%E9...
#
# [248 rows x 3 columns]

# %% [markdown]
# ## Check

# %% [markdown]
# ### Before

# %%
attraction_after_df = pd.read_csv("attraction_after.csv", encoding = "utf-16")
restaurant_after_df = pd.read_csv("restaurant_after.csv", encoding = "utf-16")
bookstore_after_df = pd.read_csv("bookstore_after.csv", encoding = "utf-16")
shopping_after_df = pd.read_csv("shopping_after.csv", encoding = "utf-16")
medical_after_df = pd.read_csv("medical_after.csv", encoding = "utf-16")

# %%
records, remove_list = set(), list()

for i in range(shopping_after_df.shape[0]):
    records.add(shopping_after_df["Title"][i])
    
for i in range(attraction_after_df.shape[0]):
    if attraction_after_df["Title"][i] in records:
        print("Attraction:", attraction_after_df["Title"][i])
        remove_list.append(("attraction_after", i))
    else:
        records.add(attraction_after_df["Title"][i])
    
for i in range(restaurant_after_df.shape[0]):
    if restaurant_after_df["Title"][i] in records:
        print("Restuarant:", restaurant_after_df["Title"][i])
        remove_list.append(("restaurant_after", i))
    else:
        records.add(restaurant_after_df["Title"][i])
    
for i in range(bookstore_after_df.shape[0]):
    if bookstore_after_df["Title"][i] in records:
        print("Bookstore:", bookstore_after_df["Title"][i])
        remove_list.append(("bookstore_after", i))
    else:
        records.add(bookstore_after_df["Title"][i])
        
for i in range(medical_after_df.shape[0]):
    if medical_after_df["Title"][i] in records:
        print("Medical:", medical_after_df["Title"][i])
        remove_list.append(("medical_after", i))
    else:
        records.add(medical_after_df["Title"][i])
# Out:
# Attraction:  新竹市城隍廟夜市
# Attraction:  桃園觀光夜市
# Attraction:  嘉義文化路夜市
# Attraction:  樹林頭觀光夜市
# Restuarant:  山口刺身ま丼飯專賣清大店#新竹美食#清大夜市美食#日本料理推薦#在地推薦美食#新竹必吃美食
# Restuarant:  Big City遠東巨城購物中心
# Restuarant:  SOGO 百貨新竹店
# Restuarant:  遠東SOGO 台北忠孝館
# Bookstore:  禾園茶館
# Bookstore:  新竹市影像博物館─或者光盒子
# Medical:  宏仁診所
# Medical:  艾美時尚診所
# Medical:  中國醫藥大學新竹附設醫院
# Medical:  寶山鄉衛生所
# Medical:  星和診所 竹北光明醫美
# Medical:  紐約牙醫診所
# Medical:  比漾皮膚科診所
# Medical:  晶綻醫美診所
# Medical:  桃園中壢長慎醫院-糖尿病/新陳代謝科/腎臟病/一般內科推薦醫院
# Medical:  上上中醫診所
# Medical:  和德中醫診所
# Medical:  鑫庚內科診所暨血液透析中心
# Medical:  桃園聖宜診所
# Medical:  家康診所
# Medical:  安泰耳鼻喉科診所

# %% [markdown]
# ### Attractions

# %%
attraction_list = [index for name, index in remove_list if name == "attraction_after"]

attraction_after_df.drop(attraction_list, axis = 0, inplace = True)
attraction_after_df.to_csv("attraction_after.csv", encoding = "utf-16", index = False)

attraction_after_df
# Out:
#                                      Title    Comments  \
# 0                                     竹湖        31 則評論
# 1                                    寄梅亭        10 則評論
# 2                                清華大學成功湖       379 則評論
# 3                                    靜心湖     2,107 則評論
# 4     沃夫帕克WolfPark 親子館(新竹親子餐廳/親子景點/室內親子)       529 則評論
# ..                                     ...         ...
# 289                                 好好聚落       395 則評論
# 290                                 宮原眼科    24,400 則評論
# 291                              鳳鼻頭文化遺址       200 則評論
# 292                               高雄市忠烈祠     1,896 則評論
# 293                            德元埤旅遊服務中心        20 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E7%AB%B9%E6...
# 1    https://www.google.com/maps/place/%E5%AF%84%E6...
# 2    https://www.google.com/maps/place/%E6%B8%85%E8...
# 3    https://www.google.com/maps/place/%E9%9D%9C%E5...
# 4    https://www.google.com/maps/place/%E6%B2%83%E5...
# ..                                                 ...
# 289  https://www.google.com/maps/place/%E5%A5%BD%E5...
# 290  https://www.google.com/maps/place/%E5%AE%AE%E5...
# 291  https://www.google.com/maps/place/%E9%B3%B3%E9...
# 292  https://www.google.com/maps/place/%E9%AB%98%E9...
# 293  https://www.google.com/maps/place/%E5%BE%B7%E5...
#
# [290 rows x 3 columns]

# %% [markdown]
# ### Restaurants

# %%
restaurant_list = [index for name, index in remove_list if name == "restaurant_after"]

restaurant_after_df.drop(restaurant_list, axis = 0, inplace = True)
restaurant_after_df.to_csv("restaurant_after.csv", encoding = "utf-16", index = False)

restaurant_after_df
# Out:
#                          Title   Comments  \
# 0     LALA Kitchen 新美式餐廳 交大店      994 則評論
# 1                    和選旅-硯宴軒      350 則評論
# 2         漢堡王Burger King 交大店      315 則評論
# 3                RINGOAL車庫餐廳      383 則評論
# 4                      橄欖樹廚房      669 則評論
# ..                         ...        ...
# 269                夠麻吉股份有限公司      409 則評論
# 270                       紓咖       20 則評論
# 271             太魯閣晶英酒店梅園中餐廳      174 則評論
# 272             CITYLINK 內湖店    1,953 則評論
# 273                     金門餐廳    1,488 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/LALA+Kitchen...
# 1    https://www.google.com/maps/place/%E5%92%8C%E9...
# 2    https://www.google.com/maps/place/%E6%BC%A2%E5...
# 3    https://www.google.com/maps/place/RINGOAL%E8%B...
# 4    https://www.google.com/maps/place/%E6%A9%84%E6...
# ..                                                 ...
# 269  https://www.google.com/maps/place/%E5%A4%A0%E9...
# 270  https://www.google.com/maps/place/%E7%B4%93%E5...
# 271  https://www.google.com/maps/place/%E5%A4%AA%E9...
# 272  https://www.google.com/maps/place/CITYLINK+%E5...
# 273  https://www.google.com/maps/place/%E9%87%91%E9...
#
# [270 rows x 3 columns]

# %% [markdown]
# ### Bookstores

# %%
bookstore_list = [index for name, index in remove_list if name == "bookstore_after"]

bookstore_after_df.drop(bookstore_list, axis = 0, inplace = True)
bookstore_after_df.to_csv("bookstore_after.csv", encoding = "utf-16", index = False)

bookstore_after_df
# Out:
#                   Title   Comments  \
# 0       麗文校園書局(交通大學店)       68 則評論
# 1                水木書苑      763 則評論
# 2                大學書局    1,231 則評論
# 3               筆耕小書店       86 則評論
# 4         校園書房(新竹勝利店)      110 則評論
# ..                  ...        ...
# 198    書屋花甲Ｘ而立書店（台大店）       84 則評論
# 199              太平青鳥      520 則評論
# 200              書屋花甲      284 則評論
# 201             練習曲書店      342 則評論
# 202   好好生活書店｜24小時無人書店       54 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E9%BA%97%E6...
# 1    https://www.google.com/maps/place/%E6%B0%B4%E6...
# 2    https://www.google.com/maps/place/%E5%A4%A7%E5...
# 3    https://www.google.com/maps/place/%E7%AD%86%E8...
# 4    https://www.google.com/maps/place/%E6%A0%A1%E5...
# ..                                                 ...
# 198  https://www.google.com/maps/place/%E6%9B%B8%E5...
# 199  https://www.google.com/maps/place/%E5%A4%AA%E5...
# 200  https://www.google.com/maps/place/%E6%9B%B8%E5...
# 201  https://www.google.com/maps/place/%E7%B7%B4%E7...
# 202  https://www.google.com/maps/place/%E5%A5%BD%E5...
#
# [201 rows x 3 columns]

# %% [markdown]
# ### Medical

# %%
medical_list = [index for name, index in remove_list if name == "medical_after"]

medical_after_df.drop(medical_list, axis = 0, inplace = True)
medical_after_df.to_csv("medical_after.csv", encoding = "utf-16", index = False)

medical_after_df
# Out:
#                 Title Comments  \
# 0              康德診所    165 則評論
# 1              長春診所    462 則評論
# 2            和杏中醫診所     55 則評論
# 3             茱麗婦產科     74 則評論
# 4           倪耳鼻喉科診所     74 則評論
# ..                ...      ...
# 243          台灣醫院協會      3 則評論
# 244          新竹縣衛生局     60 則評論
# 245          花蓮慈濟醫院    439 則評論
# 246   中國醫藥大學附設醫院急診部    249 則評論
# 247             卓醫院    129 則評論
#
#                                                    Url
# 0    https://www.google.com/maps/place/%E5%BA%B7%E5...
# 1    https://www.google.com/maps/place/%E9%95%B7%E6...
# 2    https://www.google.com/maps/place/%E5%92%8C%E6...
# 3    https://www.google.com/maps/place/%E8%8C%B1%E9...
# 4    https://www.google.com/maps/place/%E5%80%AA%E8...
# ..                                                 ...
# 243  https://www.google.com/maps/place/%E5%8F%B0%E7...
# 244  https://www.google.com/maps/place/%E6%96%B0%E7...
# 245  https://www.google.com/maps/place/%E8%8A%B1%E8...
# 246  https://www.google.com/maps/place/%E4%B8%AD%E5...
# 247  https://www.google.com/maps/place/%E5%8D%93%E9...
#
# [233 rows x 3 columns]

# %% [markdown]
# ### After

# %%
attraction_after_df = pd.read_csv("attraction_after.csv", encoding = "utf-16")
restaurant_after_df = pd.read_csv("restaurant_after.csv", encoding = "utf-16")
bookstore_after_df = pd.read_csv("bookstore_after.csv", encoding = "utf-16")
shopping_after_df = pd.read_csv("shopping_after.csv", encoding = "utf-16")
medical_after_df = pd.read_csv("medical_after.csv", encoding = "utf-16")

# %%
records, remove_list = set(), list()

for i in range(shopping_after_df.shape[0]):
    records.add(shopping_after_df["Title"][i])
    
for i in range(attraction_after_df.shape[0]):
    if attraction_after_df["Title"][i] in records:
        print("Attraction:", attraction_after_df["Title"][i])
        remove_list.append(("attraction_after", i))
    else:
        records.add(attraction_after_df["Title"][i])
    
for i in range(restaurant_after_df.shape[0]):
    if restaurant_after_df["Title"][i] in records:
        print("Restuarant:", restaurant_after_df["Title"][i])
        remove_list.append(("restaurant_after", i))
    else:
        records.add(restaurant_after_df["Title"][i])
    
for i in range(bookstore_after_df.shape[0]):
    if bookstore_after_df["Title"][i] in records:
        print("Bookstore:", bookstore_after_df["Title"][i])
        remove_list.append(("bookstore_after", i))
    else:
        records.add(bookstore_after_df["Title"][i])
        
for i in range(medical_after_df.shape[0]):
    if medical_after_df["Title"][i] in records:
        print("Medical:", medical_after_df["Title"][i])
        remove_list.append(("medical_after", i))
    else:
        records.add(medical_after_df["Title"][i])
